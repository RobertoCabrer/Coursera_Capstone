# %% [markdown]
# # **`Data Science Capstone Week 3 Assignment`**

# %% [markdown]
# ---
# ##**Web scrapping Toronto dataset**

# %% [markdown]
# **First we import all the needed packages**

# %%
#!pip install bs4 # installs beautiful soup if needed
# !pip install geocoder # installs geocoder if needed
import requests
import geocoder # import geocoder
import folium # map rendering library

import pandas as pd
import numpy as np

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans
from bs4 import BeautifulSoup
# Out:
# Requirement already satisfied: geocoder in /usr/local/lib/python3.7/dist-packages (1.38.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from geocoder) (0.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from geocoder) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from geocoder) (1.15.0)
# Requirement already satisfied: ratelim in /usr/local/lib/python3.7/dist-packages (from geocoder) (0.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from geocoder) (2.23.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ratelim->geocoder) (4.4.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (2.10)

# %% [markdown]
# **Retreiving the URL and creating a Beautiful soup object**

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

req = requests.get(url)
soup = BeautifulSoup(req.content, 'html.parser')
#print(soup.prettify())

# %% [markdown]
# **Creating the list with the table information**
#
# The next cell of code will create a list with the table objects, modified to meet the specifications:
#
# – Multiple neighborhoods in the same postal code area are be combined into one row with the neighborhoods separated with a comma.
#
# – Cells with 'Not assigned' neighborhood are renamed to their borough name.

# %% [markdown]
# More than one neighborhood can exist in one postal code area.
#
# For example, in the table on the Wikipedia page, you will notice that M5A is listed twice and has two neighborhoods: Harbourfront and Regent Park.
#
# These two rows will be combined into one row with the neighborhoods separated with a comma as shown in row 11  in the above table.
#
# If a cell has a borough but a Not assigned  neighborhood, then the neighborhood will be the same as the borough.

# %%
table_contents=[] # Firstly create a list
table=soup.find('table') # Finding the table and table data  
for row in table.findAll('td'): #
    cell = {}
    if row.span.text=='Not assigned':
        pass
    else: # Create a dictionary called cell having 3 keys PostalCode, Borough and Neighborhood
        cell['PostalCode'] = row.p.text[:3] # As postal code contains upto 3 characters extract that using tablerow.p.text
        cell['Borough'] = (row.span.text).split('(')[0] # Use split, strip and replace functions for getting Borough and Neighborhood info
        cell['Neighborhood'] = (((((row.span.text).split('(')[1]).strip(')')).replace(' /',',')).replace(')',' ')).strip(' ')
        table_contents.append(cell) # Append to the list

# %% [markdown]
# **Creating a dataframe from list**

# %%
# print(table_contents)
df=pd.DataFrame(table_contents)
df['Borough']=df['Borough'].replace({'Downtown TorontoStn A PO Boxes25 The Esplanade':'Downtown Toronto Stn A',
                                             'East TorontoBusiness reply mail Processing Centre969 Eastern':'East Toronto Business',
                                             'EtobicokeNorthwest':'Etobicoke Northwest','East YorkEast Toronto':'East York/East Toronto',
                                             'MississaugaCanada Post Gateway Processing Centre':'Mississauga'})

# %%
df.tail()
# Out:
#     PostalCode  ...                                       Neighborhood
# 98         M8X  ...      The Kingsway, Montgomery Road, Old Mill North
# 99         M4Y  ...                               Church and Wellesley
# 100        M7Y  ...                                     Enclave of M4L
# 101        M8Y  ...  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102        M8Z  ...  Mimico NW, The Queensway West, South of Bloor,...
#
# [5 rows x 3 columns]

# %% [markdown]
# ##**Obtaining longitudes and latitudes with Geocoder**
#
# Now we will use geocoder to get latitudes and longitudes for each postal code. Note that I used the ArcGIS argument instead of the Google one, because using .google. you are likely to obtain no response.

# %%
latitude=[]
longitude=[]
for code in df['PostalCode']:
    g = geocoder.arcgis('{}, Toronto, Ontario'.format(code))
    print(code, g.latlng)
    while (g.latlng is None):
        g = geocoder.arcgis('{}, Toronto, Ontario'.format(code))
        print(code, g.latlng)
    latlng = g.latlng
    latitude.append(latlng[0])
    longitude.append(latlng[1])
# Out:
# M3A [43.75245000000007, -79.32990999999998]
# M4A [43.73057000000006, -79.31305999999995]
# M5A [43.65512000000007, -79.36263999999994]
# M6A [43.72327000000007, -79.45041999999995]
# M7A [43.66253000000006, -79.39187999999996]
# M9A [43.662630000000036, -79.52830999999998]
# M1B [43.811390000000074, -79.19661999999994]
# M3B [43.74923000000007, -79.36185999999998]
# M4B [43.70718000000005, -79.31191999999999]
# M5B [43.65739000000008, -79.37803999999994]
# M6B [43.70687000000004, -79.44811999999996]
# M9B [43.65034000000003, -79.55361999999997]
# M1C [43.78574000000003, -79.15874999999994]
# M3C [43.72168000000005, -79.34351999999996]
# M4C [43.68970000000007, -79.30681999999996]
# M5C [43.65215000000006, -79.37586999999996]
# M6C [43.69211000000007, -79.43035999999995]
# M9C [43.64857000000006, -79.57824999999997]
# M1E [43.765750000000025, -79.17469999999997]
# M4E [43.67709000000008, -79.29546999999997]
# M5E [43.64536000000004, -79.37305999999995]
# M6E [43.68784000000005, -79.45045999999996]
# M1G [43.76812000000007, -79.21760999999998]
# M4G [43.709020000000066, -79.36348999999996]
# M5G [43.65609000000006, -79.38492999999994]
# M6G [43.668690000000026, -79.42070999999999]
# M1H [43.76944000000003, -79.23891999999995]
# M2H [43.80225000000007, -79.35557999999997]
# M3H [43.75788000000006, -79.44846999999999]
# M4H [43.70142000000004, -79.34904999999998]
# M5H [43.64970000000005, -79.38257999999996]
# M6H [43.665050000000065, -79.43890999999996]
# M1J [43.74446000000006, -79.23116999999996]
# M2J [43.780970000000025, -79.34780999999998]
# M3J [43.76476000000008, -79.48797999999994]
# M4J [43.68811000000005, -79.33417999999995]
# M5J [43.64285000000007, -79.38075999999995]
# M6J [43.64848000000006, -79.41773999999998]
# M1K [43.725820000000056, -79.26460999999995]
# M2K [43.781120000000044, -79.38059999999996]
# M3K [43.73384000000004, -79.46827999999994]
# M4K [43.68375000000003, -79.35511999999994]
# M5K [43.64710000000008, -79.38152999999994]
# M6K [43.639410000000055, -79.42675999999994]
# M1L [43.71289000000007, -79.28505999999999]
# M2L [43.756980000000055, -79.38059999999996]
# M3L [43.720710000000054, -79.51700999999997]
# M4L [43.667970000000025, -79.31466999999998]
# M5L [43.64840000000004, -79.37913999999995]
# M6L [43.71381000000008, -79.48873999999995]
# M9L [43.75948000000005, -79.55706999999995]
# M1M [43.72360000000003, -79.23495999999994]
# M2M [43.79182000000003, -79.41371999999996]
# M3M [43.73224000000005, -79.50177999999994]
# M4M [43.66213000000005, -79.33496999999994]
# M5M [43.73545000000007, -79.41915999999998]
# M6M [43.695170000000076, -79.48396999999994]
# M9M [43.733670000000075, -79.53768999999994]
# M1N [43.695100000000025, -79.26465999999994]
# M2N [43.76774000000006, -79.40727999999996]
# M3N [43.75478000000004, -79.51958999999994]
# M4N [43.72843000000006, -79.38712999999996]
# M5N [43.71208000000007, -79.41847999999999]
# M6N [43.67646000000008, -79.48271999999997]
# M9N [43.705070000000035, -79.51803999999998]
# M1P [43.75998000000004, -79.26939999999996]
# M2P [43.747780000000034, -79.40032999999994]
# M4P [43.71276000000006, -79.38850999999994]
# M5P [43.69479000000007, -79.41439999999994]
# M6P [43.659730000000025, -79.46280999999993]
# M9P [43.696300000000065, -79.52925999999997]
# M1R [43.75075000000004, -79.30053999999996]
# M2R [43.77989000000008, -79.44677999999999]
# M4R [43.71458000000007, -79.40667999999994]
# M5R [43.674840000000074, -79.40451999999993]
# M6R [43.64777000000004, -79.44988999999998]
# M7R [43.648690000000045, -79.38543999999996]
# M9R [43.68681000000004, -79.55727999999993]
# M1S [43.794520000000034, -79.26707999999996]
# M4S [43.703400000000045, -79.38658999999996]
# M5S [43.663110000000074, -79.40179999999998]
# M6S [43.649820000000034, -79.47547999999995]
# M1T [43.784910000000025, -79.29721999999998]
# M4T [43.690480000000036, -79.38317999999998]
# M5T [43.65351000000004, -79.39721999999995]
# M1V [43.817810000000065, -79.28043999999994]
# M4V [43.68568000000005, -79.40236999999996]
# M5V [43.640820000000076, -79.39817999999997]
# M8V [43.60987000000006, -79.49808999999993]
# M9V [43.744530000000054, -79.58623999999998]
# M1W [43.80079000000006, -79.32161999999994]
# M4W [43.68190000000004, -79.37828999999994]
# M5W [43.648690000000045, -79.38543999999996]
# M8W [43.601240000000075, -79.53878999999995]
# M9W [43.71174000000008, -79.57940999999994]
# M1X [43.83412000000004, -79.21667999999994]
# M4X [43.667880000000025, -79.36648999999994]
# M5X [43.64828000000006, -79.38145999999995]
# M8X [43.65319000000005, -79.51112999999998]
# M4Y [43.66659000000004, -79.38132999999993]
# M7Y [43.648690000000045, -79.38543999999996]
# M8Y [43.632780000000025, -79.48944999999998]
# M8Z [43.62513000000007, -79.52680999999995]

# %%
df['Latitude'] = latitude
df['Longitude'] = longitude

# %%
df.head()
# Out:
#   PostalCode           Borough  ...  Latitude  Longitude
# 0        M3A        North York  ...  43.75245  -79.32991
# 1        M4A        North York  ...  43.73057  -79.31306
# 2        M5A  Downtown Toronto  ...  43.65512  -79.36264
# 3        M6A        North York  ...  43.72327  -79.45042
# 4        M7A      Queen's Park  ...  43.66253  -79.39188
#
# [5 rows x 5 columns]

# %% [markdown]
# The latitudes and longitudes obtained by the above process might be slightly different from the ones usign geocoder.google or the ones in the CSV file, pointing towards the usage of different map projections between the service providers.

# %% [markdown]
# ## **Visualising and clustering Boroughs**
#
# Before clustering it is important to do some exploratory analysis of the data trough visualizations.
# The next code cell will create a map of Toronto with the Boroughs superimposed. Each of the labels will have the Neighborhoods in the corresponding Borough.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[df['Latitude'][0], df['Longitude'][0]], zoom_start=10) # Don't have coordinates for 'whole' Toronto, use first occurence in df instead

# add markers to map
for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_17eea010138e45ee9db04690165c83d1%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_17eea010138e45ee9db04690165c83d1%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_17eea010138e45ee9db04690165c83d1%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_17eea010138e45ee9db04690165c83d1%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B43.75245000000007%2C%20-79.32990999999998%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_f00efe911e1e48b0bb437ac18e28f05c%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0 ...

# %% [markdown]
# **Obtaining venue information using the Foursquare API**
#
# Now that the dataset has latitude and longitude for each Borough we can use the Foursquare API to obtain venue information.
#
# First it is needed to give the Client ID and Client Secret.

# %%
CLIENT_ID = 'TWMNKTMNIFKLBWACWOITLJB1FQKPYCOV4GOYI5JRQ2CBL5UI' # your Foursquare ID
CLIENT_SECRET = 'V2BHWQ2S3SURR2VO2R04EDFVLYR21TFCSYZWCJHJCCH3C3BF' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: TWMNKTMNIFKLBWACWOITLJB1FQKPYCOV4GOYI5JRQ2CBL5UI
# CLIENT_SECRET:V2BHWQ2S3SURR2VO2R04EDFVLYR21TFCSYZWCJHJCCH3C3BF

# %% [markdown]
# **Venue extraction function**

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# **Applying the function to the dataframe**

# %%
toronto_venues = getNearbyVenues(names=df['Neighborhood'], latitudes = df['Latitude'], longitudes = df['Longitude']);
# Out:
# Parkwoods
# Victoria Village
# Regent Park, Harbourfront
# Lawrence Manor, Lawrence Heights
# Ontario Provincial Government
# Islington Avenue
# Malvern, Rouge
# Don Mills North
# Parkview Hill, Woodbine Gardens
# Garden District, Ryerson
# Glencairn
# West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale
# Rouge Hill, Port Union, Highland Creek
# Don Mills South
# Woodbine Heights
# St. James Town
# Humewood-Cedarvale
# Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood
# Guildwood, Morningside, West Hill
# The Beaches
# Berczy Park
# Caledonia-Fairbanks
# Woburn
# Leaside
# Central Bay Street
# Christie
# Cedarbrae
# Hillcrest Village
# Bathurst Manor, Wilson Heights, Downsview North
# Thorncliffe Park
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# Scarborough Village
# Fairview, Henry Farm, Oriole
# Northwood Park, York University
# The Danforth  East
# Harbourfront East, Union Station, Toronto Islands
# Little Portugal, Trinity
# Kennedy Park, Ionview, East Birchmount Park
# Bayview Village
# Downsview East
# The Danforth West, Riverdale
# Toronto Dominion Centre, Design Exchange
# Brockton, Parkdale Village, Exhibition Place
# Golden Mile, Clairlea, Oakridge
# York Mills, Silver Hills
# Downsview West
# India Bazaar, The Beaches West
# Commerce Court, Victoria Hotel
# North Park, Maple Leaf Park, Upwood Park
# Humber Summit
# Cliffside, Cliffcrest, Scarborough Village West
# Willowdale, Newtonbrook
# Downsview Central
# Studio District
# Bedford Park, Lawrence Manor East
# Del Ray, Mount Dennis, Keelsdale and Silverthorn
# Humberlea, Emery
# Birch Cliff, Cliffside West
# Willowdale South
# Downsview Northwest
# Lawrence Park
# Roselawn
# Runnymede, The Junction North
# Weston
# Dorset Park, Wexford Heights, Scarborough Town Centre
# York Mills West
# Davisville North
# Forest Hill North & West
# High Park, The Junction South
# Westmount
# Wexford, Maryvale
# Willowdale West
# North Toronto West
# The Annex, North Midtown, Yorkville
# Parkdale, Roncesvalles
# Enclave of L4W
# Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens
# Agincourt
# Davisville
# University of Toronto, Harbord
# Runnymede, Swansea
# Clarks Corners, Tam O'Shanter, Sullivan
# Moore Park, Summerhill East
# Kensington Market, Chinatown, Grange Park
# Milliken, Agincourt North, Steeles East, L'Amoreaux East
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# New Toronto, Mimico South, Humber Bay Shores
# South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens
# Steeles West, L'Amoreaux West
# Rosedale
# Enclave of M5E
# Alderwood, Long Branch
# Clairville, Humberwood, Woodbine Downs, West Humber, Kipling Heights, Rexdale, Elms, Tandridge, Old Rexdale
# Upper Rouge
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# The Kingsway, Montgomery Road, Old Mill North
# Church and Wellesley
# Enclave of M4L
# Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East
# Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West

# %% [markdown]
# **Using one-hot encoding**

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_onehot.tail(10)
# Out:
#       Yoga Studio  Accessories Store  ...  Wings Joint  Women's Store
# 2419            0                  0  ...            0              0
# 2420            0                  0  ...            0              0
# 2421            0                  0  ...            0              0
# 2422            0                  0  ...            0              0
# 2423            0                  0  ...            0              0
# 2424            0                  0  ...            0              0
# 2425            0                  0  ...            0              0
# 2426            0                  0  ...            0              0
# 2427            0                  0  ...            0              0
# 2428            0                  0  ...            0              0
#
# [10 rows x 269 columns]

# %%
toronto_onehot.shape
# Out:
# (2429, 269)

# %% [markdown]
# **Grouping by venue categories and extracting the mean**

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped.tail(10)
# Out:
#                  Neighborhood  Yoga Studio  ...  Wings Joint  Women's Store
# 92                  Westmount          0.0  ...          0.0            0.0
# 93                     Weston          0.0  ...          0.0            0.0
# 94          Wexford, Maryvale          0.0  ...          0.0            0.0
# 95           Willowdale South          0.0  ...          0.0            0.0
# 96            Willowdale West          0.0  ...          0.0            0.0
# 97    Willowdale, Newtonbrook          0.0  ...          0.0            0.0
# 98                     Woburn          0.0  ...          0.0            0.0
# 99           Woodbine Heights          0.0  ...          0.0            0.0
# 100           York Mills West          0.0  ...          0.0            0.0
# 101  York Mills, Silver Hills          0.0  ...          0.0            0.0
#
# [10 rows x 269 columns]

# %%
toronto_grouped.shape
# Out:
# (102, 269)

# %% [markdown]
# The next cell of code will print the desired top venues and their frequency for each of the Boroughs or Neighborhoods list.

# %%
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Agincourt----
#                  venue  freq
# 0  Shanghai Restaurant  0.08
# 1       Discount Store  0.08
# 2          Supermarket  0.08
# 3               Bakery  0.08
# 4   Chinese Restaurant  0.08
#
#
# ----Alderwood, Long Branch----
#                 venue  freq
# 0   Convenience Store  0.25
# 1                 Pub  0.25
# 2  Athletics & Sports  0.25
# 3                 Gym  0.25
# 4  Miscellaneous Shop  0.00
#
#
# ----Bathurst Manor, Wilson Heights, Downsview North----
#                        venue  freq
# 0                Men's Store   1.0
# 1                 Nail Salon   0.0
# 2              Metro Station   0.0
# 3         Mexican Restaurant   0.0
# 4  Middle Eastern Restaurant   0.0
#
#
# ----Bayview Village----
#                         venue  freq
# 0                       Trail  0.50
# 1  Construction & Landscaping  0.25
# 2                        Park  0.25
# 3                 Music Store  0.00
# 4                      Museum  0.00
#
#
# ----Bedford Park, Lawrence Manor East----
#                 venue  freq
# 0         Coffee Shop  0.10
# 1      Sandwich Place  0.10
# 2  Italian Restaurant  0.10
# 3    Sushi Restaurant  0.05
# 4         Sports Club  0.05
#
#
# ----Berczy Park----
#           venue  freq
# 0   Coffee Shop  0.06
# 1        Bakery  0.05
# 2  Cocktail Bar  0.05
# 3    Restaurant  0.03
# 4   Cheese Shop  0.03
#
#
# ----Birch Cliff, Cliffside West----
#                    venue  freq
# 0           Skating Rink  0.25
# 1        College Stadium  0.25
# 2                   Café  0.25
# 3  General Entertainment  0.25
# 4            Yoga Studio  0.00
#
#
# ----Brockton, Parkdale Village, Exhibition Place----
#             venue  freq
# 0            Café  0.06
# 1     Coffee Shop  0.06
# 2             Bar  0.06
# 3      Restaurant  0.05
# 4  Sandwich Place  0.04
#
#
# ----CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport----
#                 venue  freq
# 0  Italian Restaurant  0.08
# 1         Coffee Shop  0.06
# 2                Café  0.05
# 3                 Bar  0.04
# 4       Grocery Store  0.04
#
#
# ----Caledonia-Fairbanks----
#                  venue  freq
# 0                  Gym  0.14
# 1  Sporting Goods Shop  0.14
# 2           Beer Store  0.14
# 3                 Café  0.14
# 4                 Park  0.14
#
#
# ----Cedarbrae----
#          venue  freq
# 0        Trail  0.33
# 1  Gaming Cafe  0.33
# 2       Lounge  0.33
# 3  Yoga Studio  0.00
# 4       Museum  0.00
#
#
# ----Central Bay Street----
#             venue  freq
# 0     Coffee Shop  0.10
# 1  Clothing Store  0.09
# 2           Plaza  0.04
# 3  Cosmetics Shop  0.03
# 4             Spa  0.03
#
#
# ----Christie----
#                 venue  freq
# 0                Café  0.27
# 1       Grocery Store  0.18
# 2  Italian Restaurant  0.09
# 3          Playground  0.09
# 4          Baby Store  0.09
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0          Coffee Shop  0.11
# 1  Japanese Restaurant  0.06
# 2              Gay Bar  0.05
# 3           Restaurant  0.05
# 4     Sushi Restaurant  0.05
#
#
# ----Clairville, Humberwood, Woodbine Downs, West Humber, Kipling Heights, Rexdale, Elms, Tandridge, Old Rexdale----
#                        venue  freq
# 0                        Gym  0.14
# 1  Middle Eastern Restaurant  0.14
# 2                 Restaurant  0.14
# 3                Gas Station  0.14
# 4             Sandwich Place  0.14
#
#
# ----Clarks Corners, Tam O'Shanter, Sullivan----
#                   venue  freq
# 0  Fast Food Restaurant  0.15
# 1  Cantonese Restaurant  0.08
# 2              Pharmacy  0.08
# 3           Pizza Place  0.08
# 4            Hobby Shop  0.08
#
#
# ----Cliffside, Cliffcrest, Scarborough Village West----
#             venue  freq
# 0  Ice Cream Shop  0.22
# 1        Pharmacy  0.11
# 2     Pizza Place  0.11
# 3  Sandwich Place  0.11
# 4      Restaurant  0.11
#
#
# ----Commerce Court, Victoria Hotel----
#                 venue  freq
# 0         Coffee Shop  0.11
# 1               Hotel  0.06
# 2          Restaurant  0.06
# 3                Café  0.05
# 4  Italian Restaurant  0.04
#
#
# ----Davisville----
#             venue  freq
# 0    Dessert Shop  0.12
# 1            Café  0.08
# 2     Pizza Place  0.08
# 3     Coffee Shop  0.08
# 4  Sandwich Place  0.08
#
#
# ----Davisville North----
#                   venue  freq
# 0            Playground   0.1
# 1  Gym / Fitness Center   0.1
# 2                  Park   0.1
# 3      Department Store   0.1
# 4     Food & Drink Shop   0.1
#
#
# ----Del Ray, Mount Dennis, Keelsdale and Silverthorn----
#                   venue  freq
# 0  Fast Food Restaurant  0.50
# 1            Playground  0.25
# 2           Coffee Shop  0.25
# 3           Music Store  0.00
# 4                Museum  0.00
#
#
# ----Don Mills North----
#           venue  freq
# 0   Coffee Shop   0.2
# 1   Gas Station   0.2
# 2  Burger Joint   0.2
# 3          Park   0.2
# 4  Intersection   0.2
#
#
# ----Don Mills South----
#              venue  freq
# 0  Bubble Tea Shop  0.12
# 1     Intersection  0.12
# 2      Supermarket  0.12
# 3   Clothing Store  0.12
# 4      Coffee Shop  0.12
#
#
# ----Dorset Park, Wexford Heights, Scarborough Town Centre----
#                        venue  freq
# 0             Shipping Store  0.33
# 1                  Gift Shop  0.33
# 2                     Bakery  0.33
# 3         Mexican Restaurant  0.00
# 4  Middle Eastern Restaurant  0.00
#
#
# ----Downsview Central----
#                  venue  freq
# 0     Insurance Office   1.0
# 1          Yoga Studio   0.0
# 2  Monument / Landmark   0.0
# 3          Music Store   0.0
# 4               Museum   0.0
#
#
# ----Downsview East----
#                        venue  freq
# 0         Turkish Restaurant  0.22
# 1                     Bakery  0.11
# 2                Pizza Place  0.11
# 3      Vietnamese Restaurant  0.11
# 4  Latin American Restaurant  0.11
#
#
# ----Downsview Northwest----
#             venue  freq
# 0     Pizza Place  0.10
# 1   Grocery Store  0.10
# 2   Shopping Mall  0.10
# 3  Discount Store  0.10
# 4        Pharmacy  0.05
#
#
# ----Downsview West----
#                   venue  freq
# 0                 Hotel  0.17
# 1                Bakery  0.08
# 2  Fast Food Restaurant  0.08
# 3        Discount Store  0.08
# 4      Department Store  0.08
#
#
# ----Dufferin, Dovercourt Village----
#                   venue  freq
# 0         Grocery Store  0.11
# 1                  Park  0.11
# 2                  Bank  0.06
# 3  Gym / Fitness Center  0.06
# 4            Smoke Shop  0.06
#
#
# ----Enclave of L4W----
#          venue  freq
# 0  Coffee Shop  0.09
# 1        Hotel  0.05
# 2   Restaurant  0.04
# 3          Bar  0.03
# 4          Pub  0.02
#
#
# ----Enclave of M4L----
#          venue  freq
# 0  Coffee Shop  0.09
# 1        Hotel  0.05
# 2   Restaurant  0.04
# 3          Bar  0.03
# 4          Pub  0.02
#
#
# ----Enclave of M5E----
#          venue  freq
# 0  Coffee Shop  0.09
# 1        Hotel  0.05
# 2   Restaurant  0.04
# 3          Bar  0.03
# 4          Pub  0.02
#
#
# ----Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood----
#                 venue  freq
# 0   Electronics Store  0.17
# 1   Fish & Chips Shop  0.17
# 2                Park  0.17
# 3  College Rec Center  0.17
# 4       Shopping Mall  0.17
#
#
# ----Fairview, Henry Farm, Oriole----
#                   venue  freq
# 0        Clothing Store  0.18
# 1            Restaurant  0.08
# 2  Fast Food Restaurant  0.06
# 3           Coffee Shop  0.06
# 4   Japanese Restaurant  0.04
#
#
# ----First Canadian Place, Underground city----
#          venue  freq
# 0  Coffee Shop  0.14
# 1        Hotel  0.07
# 2         Café  0.07
# 3          Gym  0.04
# 4   Restaurant  0.04
#
#
# ----Forest Hill North & West----
#                  venue  freq
# 0     Business Service   0.5
# 1                 Park   0.5
# 2          Yoga Studio   0.0
# 3  Monument / Landmark   0.0
# 4          Music Store   0.0
#
#
# ----Garden District, Ryerson----
#                        venue  freq
# 0                Coffee Shop  0.11
# 1             Clothing Store  0.07
# 2                       Café  0.04
# 3  Middle Eastern Restaurant  0.03
# 4             Cosmetics Shop  0.03
#
#
# ----Glencairn----
#                       venue  freq
# 0               Pizza Place  0.17
# 1             Grocery Store  0.17
# 2          Asian Restaurant  0.08
# 3  Mediterranean Restaurant  0.08
# 4      Fast Food Restaurant  0.08
#
#
# ----Golden Mile, Clairlea, Oakridge----
#            venue  freq
# 0   Intersection  0.22
# 1    Coffee Shop  0.22
# 2         Bakery  0.22
# 3  Metro Station  0.11
# 4   Soccer Field  0.11
#
#
# ----Guildwood, Morningside, West Hill----
#                              venue  freq
# 0       Construction & Landscaping  0.33
# 1                             Park  0.33
# 2             Gym / Fitness Center  0.33
# 3  Molecular Gastronomy Restaurant  0.00
# 4                      Music Store  0.00
#
#
# ----Harbourfront East, Union Station, Toronto Islands----
#                  venue  freq
# 0          Coffee Shop  0.12
# 1                Hotel  0.07
# 2           Restaurant  0.05
# 3  Japanese Restaurant  0.05
# 4        Boat or Ferry  0.03
#
#
# ----High Park, The Junction South----
#                                       venue  freq
# 0                         Convenience Store  0.25
# 1                            Sandwich Place  0.25
# 2  Residential Building (Apartment / Condo)  0.25
# 3                                      Park  0.25
# 4                       Moroccan Restaurant  0.00
#
#
# ----Hillcrest Village----
#                                       venue  freq
# 0                                     Trail  0.33
# 1  Residential Building (Apartment / Condo)  0.33
# 2                                      Park  0.33
# 3                               Yoga Studio  0.00
# 4                                    Museum  0.00
#
#
# ----Humber Summit----
#                         venue  freq
# 0  Construction & Landscaping  0.67
# 1            Business Service  0.33
# 2                 Yoga Studio  0.00
# 3         Moroccan Restaurant  0.00
# 4                 Music Venue  0.00
#
#
# ----Humberlea, Emery----
#                        venue  freq
# 0                Coffee Shop  0.50
# 1                       Park  0.25
# 2                  Nightclub  0.25
# 3  Middle Eastern Restaurant  0.00
# 4         Miscellaneous Shop  0.00
#
#
# ----Humewood-Cedarvale----
#            venue  freq
# 0   Hockey Arena  0.17
# 1  Grocery Store  0.17
# 2   Tennis Court  0.17
# 3          Field  0.17
# 4           Park  0.17
#
#
# ----India Bazaar, The Beaches West----
#                venue  freq
# 0        Pizza Place  0.09
# 1               Park  0.09
# 2     Sandwich Place  0.09
# 3  Food & Drink Shop  0.05
# 4                Pub  0.05
#
#
# ----Islington Avenue----
#           venue  freq
# 0      Pharmacy  0.22
# 1  Home Service  0.11
# 2          Café  0.11
# 3          Park  0.11
# 4  Skating Rink  0.11
#
#
# ----Kennedy Park, Ionview, East Birchmount Park----
#                         venue  freq
# 0              Discount Store   0.4
# 1          Chinese Restaurant   0.2
# 2                 Coffee Shop   0.2
# 3            Department Store   0.2
# 4  Modern European Restaurant   0.0
#
#
# ----Kensington Market, Chinatown, Grange Park----
#                    venue  freq
# 0                   Café  0.09
# 1  Vietnamese Restaurant  0.05
# 2                    Bar  0.05
# 3           Cocktail Bar  0.04
# 4           Burger Joint  0.04
#
#
# ----Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens----
#                  venue  freq
# 0          Pizza Place  0.25
# 1  Arts & Crafts Store  0.25
# 2             Bus Line  0.25
# 3        Jewelry Store  0.25
# 4            Pet Store  0.00
#
#
# ----Lawrence Manor, Lawrence Heights----
#                     venue  freq
# 0          Clothing Store  0.22
# 1           Women's Store  0.06
# 2        Toy / Game Store  0.04
# 3  Furniture / Home Store  0.04
# 4              Food Court  0.04
#
#
# ----Lawrence Park----
#                  venue  freq
# 0          Swim School   0.5
# 1             Bus Line   0.5
# 2          Yoga Studio   0.0
# 3  Monument / Landmark   0.0
# 4          Music Store   0.0
#
#
# ----Leaside----
#                  venue  freq
# 0          Coffee Shop  0.10
# 1  Sporting Goods Shop  0.10
# 2         Burger Joint  0.06
# 3                 Bank  0.06
# 4         Dessert Shop  0.03
#
#
# ----Little Portugal, Trinity----
#                    venue  freq
# 0           Cocktail Bar  0.07
# 1            Coffee Shop  0.05
# 2             Restaurant  0.05
# 3  Vietnamese Restaurant  0.05
# 4                    Bar  0.05
#
#
# ----Malvern, Rouge----
#                        venue  freq
# 0       Fast Food Restaurant   1.0
# 1                Yoga Studio   0.0
# 2                 Nail Salon   0.0
# 3         Mexican Restaurant   0.0
# 4  Middle Eastern Restaurant   0.0
#
#
# ----Milliken, Agincourt North, Steeles East, L'Amoreaux East----
#                  venue  freq
# 0             Pharmacy   0.5
# 1         Intersection   0.5
# 2          Yoga Studio   0.0
# 3  Monument / Landmark   0.0
# 4          Music Store   0.0
#
#
# ----Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West----
#                          venue  freq
# 0  Eastern European Restaurant  0.09
# 1         Gym / Fitness Center  0.09
# 2            Food & Drink Shop  0.09
# 3               Mattress Store  0.09
# 4           Miscellaneous Shop  0.09
#
#
# ----Moore Park, Summerhill East----
#                        venue  freq
# 0          Convenience Store  0.25
# 1                      Trail  0.25
# 2                 Restaurant  0.25
# 3                        Gym  0.25
# 4  Middle Eastern Restaurant  0.00
#
#
# ----New Toronto, Mimico South, Humber Bay Shores----
#            venue  freq
# 0    Yoga Studio  0.17
# 1           Park  0.17
# 2   Skating Rink  0.17
# 3   Tennis Court  0.17
# 4  Grocery Store  0.17
#
#
# ----North Park, Maple Leaf Park, Upwood Park----
#                  venue  freq
# 0               Bakery  0.33
# 1     Basketball Court  0.33
# 2                 Park  0.33
# 3  Monument / Landmark  0.00
# 4          Music Store  0.00
#
#
# ----North Toronto West----
#                              venue  freq
# 0                       Playground  0.33
# 1                         Gym Pool  0.33
# 2                             Park  0.33
# 3  Molecular Gastronomy Restaurant  0.00
# 4                      Music Store  0.00
#
#
# ----Northwood Park, York University----
#                     venue  freq
# 0  Furniture / Home Store  0.17
# 1                     Bar  0.08
# 2         Automotive Shop  0.08
# 3             Pizza Place  0.08
# 4    Caribbean Restaurant  0.08
#
#
# ----Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East----
#                   venue  freq
# 0    Chinese Restaurant  0.14
# 1    Italian Restaurant  0.14
# 2           Flower Shop  0.14
# 3  Fast Food Restaurant  0.14
# 4      Sushi Restaurant  0.14
#
#
# ----Ontario Provincial Government----
#                 venue  freq
# 0         Coffee Shop  0.25
# 1       Burrito Place  0.06
# 2  Italian Restaurant  0.06
# 3                Bank  0.06
# 4      Sandwich Place  0.06
#
#
# ----Parkdale, Roncesvalles----
#                          venue  freq
# 0                  Coffee Shop  0.07
# 1             Sushi Restaurant  0.05
# 2                         Café  0.05
# 3                       Bakery  0.05
# 4  Eastern European Restaurant  0.05
#
#
# ----Parkview Hill, Woodbine Gardens----
#                 venue  freq
# 0         Pizza Place  0.14
# 1  Athletics & Sports  0.07
# 2            Pharmacy  0.07
# 3           Pet Store  0.07
# 4         Flea Market  0.07
#
#
# ----Parkwoods----
#                              venue  freq
# 0       Construction & Landscaping  0.25
# 1                Food & Drink Shop  0.25
# 2             Fast Food Restaurant  0.25
# 3                             Park  0.25
# 4  Molecular Gastronomy Restaurant  0.00
#
#
# ----Regent Park, Harbourfront----
#             venue  freq
# 0     Coffee Shop  0.23
# 1  Breakfast Spot  0.09
# 2         Theater  0.05
# 3      Food Truck  0.05
# 4             Spa  0.05
#
#
# ----Richmond, Adelaide, King----
#                  venue  freq
# 0                Hotel  0.06
# 1                 Café  0.06
# 2          Coffee Shop  0.06
# 3                  Gym  0.04
# 4  Japanese Restaurant  0.04
#
#
# ----Rosedale----
#                   venue  freq
# 0            Playground  0.25
# 1          Tennis Court  0.25
# 2  Gym / Fitness Center  0.25
# 3                  Park  0.25
# 4           Yoga Studio  0.00
#
#
# ----Roselawn----
#                              venue  freq
# 0                     Home Service  0.67
# 1             Fast Food Restaurant  0.33
# 2  Molecular Gastronomy Restaurant  0.00
# 3                      Music Store  0.00
# 4                           Museum  0.00
#
#
# ----Rouge Hill, Port Union, Highland Creek----
#                  venue  freq
# 0                  Bar   1.0
# 1          Yoga Studio   0.0
# 2  Monument / Landmark   0.0
# 3          Music Store   0.0
# 4               Museum   0.0
#
#
# ----Runnymede, Swansea----
#          venue  freq
# 0  Coffee Shop  0.10
# 1         Café  0.10
# 2       Bakery  0.07
# 3  Pizza Place  0.05
# 4         Bank  0.05
#
#
# ----Runnymede, The Junction North----
#                     venue  freq
# 0  Furniture / Home Store   0.6
# 1      Seafood Restaurant   0.2
# 2                 Brewery   0.2
# 3             Yoga Studio   0.0
# 4     Monument / Landmark   0.0
#
#
# ----Scarborough Village----
#                         venue  freq
# 0               Grocery Store  0.25
# 1                         Spa  0.25
# 2                        Park  0.25
# 3           Indian Restaurant  0.25
# 4  Modern European Restaurant  0.00
#
#
# ----South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens----
#                   venue  freq
# 0         Grocery Store  0.13
# 1   Japanese Restaurant  0.07
# 2        Discount Store  0.07
# 3  Caribbean Restaurant  0.07
# 4            Beer Store  0.07
#
#
# ----St. James Town----
#                 venue  freq
# 0         Coffee Shop  0.07
# 1      Cosmetics Shop  0.05
# 2  Italian Restaurant  0.05
# 3          Restaurant  0.05
# 4                Café  0.03
#
#
# ----St. James Town, Cabbagetown----
#          venue  freq
# 0         Café  0.06
# 1  Pizza Place  0.06
# 2   Restaurant  0.06
# 3  Coffee Shop  0.06
# 4       Market  0.04
#
#
# ----Steeles West, L'Amoreaux West----
#                   venue  freq
# 0  Fast Food Restaurant  0.15
# 1        Cosmetics Shop  0.08
# 2           Coffee Shop  0.08
# 3           Pizza Place  0.08
# 4           Supermarket  0.08
#
#
# ----Studio District----
#                  venue  freq
# 0                Diner  0.06
# 1              Brewery  0.06
# 2   Italian Restaurant  0.06
# 3            Gastropub  0.04
# 4  American Restaurant  0.04
#
#
# ----Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park----
#                 venue  freq
# 0         Coffee Shop  0.29
# 1  Light Rail Station  0.29
# 2        Liquor Store  0.14
# 3         Supermarket  0.14
# 4  Athletics & Sports  0.14
#
#
# ----The Annex, North Midtown, Yorkville----
#                 venue  freq
# 0      Sandwich Place  0.13
# 1                Café  0.09
# 2                 Pub  0.04
# 3  Italian Restaurant  0.04
# 4        Liquor Store  0.04
#
#
# ----The Beaches----
#                venue  freq
# 0              Trail  0.25
# 1  Health Food Store  0.25
# 2                Pub  0.25
# 3        Yoga Studio  0.00
# 4        Music Store  0.00
#
#
# ----The Danforth  East----
#           venue  freq
# 0  Intersection  0.50
# 1      Bus Stop  0.25
# 2          Park  0.25
# 3   Yoga Studio  0.00
# 4   Music Store  0.00
#
#
# ----The Danforth West, Riverdale----
#             venue  freq
# 0        Bus Line  0.12
# 1  Ice Cream Shop  0.12
# 2            Park  0.12
# 3    Intersection  0.12
# 4  Discount Store  0.12
#
#
# ----The Kingsway, Montgomery Road, Old Mill North----
#                              venue  freq
# 0                           Lounge   1.0
# 1                      Yoga Studio   0.0
# 2  Molecular Gastronomy Restaurant   0.0
# 3                      Music Store   0.0
# 4                           Museum   0.0
#
#
# ----Thorncliffe Park----
#             venue  freq
# 0     Yoga Studio  0.08
# 1    Intersection  0.08
# 2          Bridge  0.08
# 3     Pizza Place  0.08
# 4  Sandwich Place  0.08
#
#
# ----Toronto Dominion Centre, Design Exchange----
#                  venue  freq
# 0          Coffee Shop  0.12
# 1                Hotel  0.08
# 2                 Café  0.06
# 3           Restaurant  0.05
# 4  Japanese Restaurant  0.03
#
#
# ----University of Toronto, Harbord----
#        venue  freq
# 0       Café  0.11
# 1     Bakery  0.06
# 2  Bookstore  0.04
# 3        Gym  0.04
# 4        Bar  0.04
#
#
# ----Victoria Village----
#                              venue  freq
# 0                    Grocery Store  0.33
# 1                             Park  0.33
# 2                       Nail Salon  0.33
# 3  Molecular Gastronomy Restaurant  0.00
# 4                      Music Store  0.00
#
#
# ----West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale----
#                  venue  freq
# 0          Pizza Place   0.4
# 1   Chinese Restaurant   0.2
# 2       Sandwich Place   0.2
# 3             Tea Room   0.2
# 4  Peruvian Restaurant   0.0
#
#
# ----Westmount----
#                        venue  freq
# 0                Pizza Place  0.33
# 1                Coffee Shop  0.17
# 2  Middle Eastern Restaurant  0.17
# 3             Sandwich Place  0.17
# 4         Chinese Restaurant  0.17
#
#
# ----Weston----
#                  venue  freq
# 0    Convenience Store  0.17
# 1                Diner  0.17
# 2        Jewelry Store  0.17
# 3  Fried Chicken Joint  0.17
# 4             Pharmacy  0.17
#
#
# ----Wexford, Maryvale----
#                  venue  freq
# 0    Convenience Store   0.5
# 1          Auto Garage   0.5
# 2  Moroccan Restaurant   0.0
# 3          Music Venue   0.0
# 4          Music Store   0.0
#
#
# ----Willowdale South----
#                   venue  freq
# 0           Coffee Shop  0.08
# 1  Fast Food Restaurant  0.08
# 2         Shopping Mall  0.08
# 3       Bubble Tea Shop  0.04
# 4                  Bank  0.04
#
#
# ----Willowdale West----
#          venue  freq
# 0  Pizza Place  0.17
# 1         Park  0.17
# 2   Baby Store  0.17
# 3  Supermarket  0.17
# 4  Coffee Shop  0.17
#
#
# ----Willowdale, Newtonbrook----
#                        venue  freq
# 0  Middle Eastern Restaurant  0.14
# 1          Korean Restaurant  0.14
# 2                Pizza Place  0.10
# 3                       Café  0.10
# 4                Supermarket  0.05
#
#
# ----Woburn----
#                         venue  freq
# 0  Construction & Landscaping  0.25
# 1                 Coffee Shop  0.25
# 2            Business Service  0.25
# 3                        Park  0.25
# 4  Modern European Restaurant  0.00
#
#
# ----Woodbine Heights----
#            venue  freq
# 0  Grocery Store  0.11
# 1       Bus Line  0.11
# 2       Pharmacy  0.11
# 3  Metro Station  0.05
# 4    Pizza Place  0.05
#
#
# ----York Mills West----
#                              venue  freq
# 0                Convenience Store  0.33
# 1                        Speakeasy  0.33
# 2                             Park  0.33
# 3  Molecular Gastronomy Restaurant  0.00
# 4                           Museum  0.00
#
#
# ----York Mills, Silver Hills----
#                              venue  freq
# 0                      Music Venue   0.5
# 1                             Park   0.5
# 2  Molecular Gastronomy Restaurant   0.0
# 3                      Music Store   0.0
# 4                           Museum   0.0

# %% [markdown]
# **Creating function that extracts top venues and inserts them in a dataframe**

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                       Neighborhood  ... 10th Most Common Venue
# 0                                        Agincourt  ...        Badminton Court
# 1                           Alderwood, Long Branch  ...      Elementary School
# 2  Bathurst Manor, Wilson Heights, Downsview North  ...            Escape Room
# 3                                  Bayview Village  ...            Escape Room
# 4                Bedford Park, Lawrence Manor East  ...      Indian Restaurant
#
# [5 rows x 11 columns]

# %% [markdown]
# **Clustering with K-means**

# %%
# set number of clusters
kclusters = 10

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 1, 4, 0, 1, 1, 1, 1, 1, 1], dtype=int32)

# %% [markdown]
# **Creating a merged dataset with the top venues and the cluster label**

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = df.groupby('Neighborhood').mean().reset_index()

# merge toronto_grouped with df to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.dropna(inplace=True)

toronto_merged.tail() # check the last columns!
# Out:
#                  Neighborhood  ...  10th Most Common Venue
# 98    Willowdale, Newtonbrook  ...             Supermarket
# 99                     Woburn  ...       Elementary School
# 100          Woodbine Heights  ...             Gas Station
# 101           York Mills West  ...       Elementary School
# 102  York Mills, Silver Hills  ...    Ethiopian Restaurant
#
# [5 rows x 14 columns]

# %% [markdown]
# **Finally, a map of the city with the clustered Neigborhoods**

# %%
# create map
map_clusters = folium.Map(location=[df['Latitude'][0], df['Longitude'][0]], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_cbbe4c632cae4f5b96942964c4e34b0b%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_cbbe4c632cae4f5b96942964c4e34b0b%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_cbbe4c632cae4f5b96942964c4e34b0b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_cbbe4c632cae4f5b96942964c4e34b0b%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B43.75245000000007%2C%20-79.32990999999998%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_b7822865710c4953b56b6971b34f7206%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0 ...
